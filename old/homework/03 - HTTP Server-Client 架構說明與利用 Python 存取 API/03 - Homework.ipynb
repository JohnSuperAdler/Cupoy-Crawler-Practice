# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json

# %%
r = requests.get('https://api.github.com/events')

print(type(r))
print(type(r.text))
print(r.text)
# Out:
# <class 'requests.models.Response'>
# <class 'str'>
# [{"id":"22855578331","type":"PullRequestEvent","actor":{"id":82230642,"login":"WanderDinizVeloso","display_login":"WanderDinizVeloso","gravatar_id":"","url":"https://api.github.com/users/WanderDinizVeloso","avatar_url":"https://avatars.githubusercontent.com/u/82230642?"},"repo":{"id":402884026,"name":"seedz-ag/sdz-agent","url":"https://api.github.com/repos/seedz-ag/sdz-agent"},"payload":{"action":"closed","number":48,"pull_request":{"url":"https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48","id":995559870,"node_id":"PR_kwDOGAOFus47Vwm-","html_url":"https://github.com/seedz-ag/sdz-agent/pull/48","diff_url":"https://github.com/seedz-ag/sdz-agent/pull/48.diff","patch_url":"https://github.com/seedz-ag/sdz-agent/pull/48.patch","issue_url":"https://api.github.com/repos/seedz-ag/sdz-agent/issues/48","number":48,"state":"closed","locked":false,"title":"Bug/restart windows service","user":{"login":"bigjoevtrj","id":4386356,"node_id":"MDQ6VXNlcjQzODYzNTY=","avatar_url":"https://avatars.githubusercontent.com/u/4386356?v=4","gravatar_id":"","url":"https://api.github.com/users/bigjoevtrj","html_url":"https://github.com/bigjoevtrj","followers_url":"https://api.github.com/users/bigjoevtrj/followers","following_url":"https://api.github.com/users/bigjoevtrj/following{/other_user}","gists_url":"https://api.github.com/users/bigjoevtrj/gists{/gist_id}","starred_url":"https://api.github.com/users/bigjoevtrj/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/bigjoevtrj/subscriptions","organizations_url":"https://api.github.com/users/bigjoevtrj/orgs","repos_url":"https://api.github.com/users/bigjoevtrj/repos","events_url":"https://api.github.com/users/bigjoevtrj/events{/privacy}","received_events_url":"https://api.github.com/users/bigjoevtrj/received_events","type":"User","site_admin":false},"body":null,"created_at":"2022-07-13T14:14:36Z","updated_at":"2022-07-13T14:15:52Z","closed_at":"2022-07-13T14:15:51Z","merged_at":"2022-07-13T14:15:51Z","merge_commit_sha":"d2b73a56df39e7326ded5b3e35091f2b79cdf6d3","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48/commits","review_comments_url":"https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48/comments","review_comment_url":"https://api.github.com/repos/seedz-ag/sdz-agent/pulls/comments{/number}","comments_url":"https://api.github.com/repos/seedz-ag/sdz-agent/issues/48/comments","statuses_url":"https://api.github.com/repos/seedz-ag/sdz-agent/statuses/df9eec15078fab00db007f5087ff4fd7da55edc1","head":{"label":"seedz-ag:bug/restart-windows-service","ref":"bug/restart-windows-service","sha":"df9eec15078fab00db007f5087ff4fd7da55edc1","user":{"login":"seedz-ag","id":88738060,"node_id":"MDEyOk9yZ2FuaXphdGlvbjg4NzM4MDYw","avatar_url":"https://avatars.githubusercontent.com/u/88738060?v=4","gravatar_id":"","url":"https://api.github.com/users/seedz-ag","html_url":"https://github.com/seedz-ag","followers_url":"https://api.github.com/users/seedz-ag/followers","following_url":"https://api.github.com/users/seedz-ag/following{/other_user}","gists_url":"https://api.github.com/users/seedz-ag/gists{/gist_id}","starred_url":"https://api.github.com/users/seedz-ag/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/seedz-ag/subscriptions","organizations_url":"https://api.github.com/users/seedz-ag/orgs","repos_url":"https://api.github.com/users/seedz-ag/repos","events_url":"https://api.github.com/users/seedz-ag/events{/privacy}","received_events_url":"https://api.github.com/users/seedz-ag/received_events","type":"Organization","site_admin":false},"repo":{"id":402884026,"node_id":"MDEwOlJlcG9zaXRvcnk0MDI4ODQwMjY=","name":"sdz-agent","full_name":"seedz-ag/sdz-agent","private":false,"owner":{"login":"seedz-ag","id":88738060,"node_id":"MDEyOk9yZ2FuaXphdGlvbjg4NzM4MDYw","avatar_url":"https://avatars.githubusercontent.com/u/88738060?v=4","gra ...

# %%
r.text[:5]
# Out:
# '[{"id'

# %%
r_jload = json.loads(r.text)
print(type(r_jload))
print(r_jload)
# Out:
# <class 'list'>
# [{'id': '22855578331', 'type': 'PullRequestEvent', 'actor': {'id': 82230642, 'login': 'WanderDinizVeloso', 'display_login': 'WanderDinizVeloso', 'gravatar_id': '', 'url': 'https://api.github.com/users/WanderDinizVeloso', 'avatar_url': 'https://avatars.githubusercontent.com/u/82230642?'}, 'repo': {'id': 402884026, 'name': 'seedz-ag/sdz-agent', 'url': 'https://api.github.com/repos/seedz-ag/sdz-agent'}, 'payload': {'action': 'closed', 'number': 48, 'pull_request': {'url': 'https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48', 'id': 995559870, 'node_id': 'PR_kwDOGAOFus47Vwm-', 'html_url': 'https://github.com/seedz-ag/sdz-agent/pull/48', 'diff_url': 'https://github.com/seedz-ag/sdz-agent/pull/48.diff', 'patch_url': 'https://github.com/seedz-ag/sdz-agent/pull/48.patch', 'issue_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/issues/48', 'number': 48, 'state': 'closed', 'locked': False, 'title': 'Bug/restart windows service', 'user': {'login': 'bigjoevtrj', 'id': 4386356, 'node_id': 'MDQ6VXNlcjQzODYzNTY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4386356?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/bigjoevtrj', 'html_url': 'https://github.com/bigjoevtrj', 'followers_url': 'https://api.github.com/users/bigjoevtrj/followers', 'following_url': 'https://api.github.com/users/bigjoevtrj/following{/other_user}', 'gists_url': 'https://api.github.com/users/bigjoevtrj/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/bigjoevtrj/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/bigjoevtrj/subscriptions', 'organizations_url': 'https://api.github.com/users/bigjoevtrj/orgs', 'repos_url': 'https://api.github.com/users/bigjoevtrj/repos', 'events_url': 'https://api.github.com/users/bigjoevtrj/events{/privacy}', 'received_events_url': 'https://api.github.com/users/bigjoevtrj/received_events', 'type': 'User', 'site_admin': False}, 'body': None, 'created_at': '2022-07-13T14:14:36Z', 'updated_at': '2022-07-13T14:15:52Z', 'closed_at': '2022-07-13T14:15:51Z', 'merged_at': '2022-07-13T14:15:51Z', 'merge_commit_sha': 'd2b73a56df39e7326ded5b3e35091f2b79cdf6d3', 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48/commits', 'review_comments_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48/comments', 'review_comment_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/issues/48/comments', 'statuses_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/statuses/df9eec15078fab00db007f5087ff4fd7da55edc1', 'head': {'label': 'seedz-ag:bug/restart-windows-service', 'ref': 'bug/restart-windows-service', 'sha': 'df9eec15078fab00db007f5087ff4fd7da55edc1', 'user': {'login': 'seedz-ag', 'id': 88738060, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg4NzM4MDYw', 'avatar_url': 'https://avatars.githubusercontent.com/u/88738060?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/seedz-ag', 'html_url': 'https://github.com/seedz-ag', 'followers_url': 'https://api.github.com/users/seedz-ag/followers', 'following_url': 'https://api.github.com/users/seedz-ag/following{/other_user}', 'gists_url': 'https://api.github.com/users/seedz-ag/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/seedz-ag/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/seedz-ag/subscriptions', 'organizations_url': 'https://api.github.com/users/seedz-ag/orgs', 'repos_url': 'https://api.github.com/users/seedz-ag/repos', 'events_url': 'https://api.github.com/users/seedz-ag/events{/privacy}', 'received_events_url': 'https://api.github.com/users/seedz-ag/received_events', 'type': 'Organization', 'site_admin': False}, 'repo': {'id': 402884026, 'node_id': 'MDEwOlJlcG9zaXRvcnk0MDI4ODQwMjY=', 'name': 'sdz-agent', 'full_name': 'seedz-ag/sdz-agent ...

# %%
print(len(r_jload))
print(type(r_jload[0]))
print(r_jload[0].keys())
# Out:
# 30
# <class 'dict'>
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at', 'org'])

# %% [markdown]
# ### Ans.
#
# - r.text是字串形式，包含了上下括號、冒號、逗號全部都被背在字串裡
# - json.loads(r.text)將r.text轉化為list(dict_1, dict_2, ...)的形式，資料階層化，提取資料比較方便。

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r_2 = requests.get('https://cat-fact.herokuapp.com/facts')
r_2_jload = json.loads(r_2.text)

print(type(r_2_jload))
print(len(r_2_jload))
print(type(r_2_jload[0]))
print(r_2_jload[0].keys())
# Out:
# <class 'list'>
# 5
# <class 'dict'>
# dict_keys(['status', '_id', 'user', 'text', '__v', 'source', 'updatedAt', 'type', 'createdAt', 'deleted', 'used'])

# %%
print(r_jload[0])
# Out:
# {'id': '22855578331', 'type': 'PullRequestEvent', 'actor': {'id': 82230642, 'login': 'WanderDinizVeloso', 'display_login': 'WanderDinizVeloso', 'gravatar_id': '', 'url': 'https://api.github.com/users/WanderDinizVeloso', 'avatar_url': 'https://avatars.githubusercontent.com/u/82230642?'}, 'repo': {'id': 402884026, 'name': 'seedz-ag/sdz-agent', 'url': 'https://api.github.com/repos/seedz-ag/sdz-agent'}, 'payload': {'action': 'closed', 'number': 48, 'pull_request': {'url': 'https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48', 'id': 995559870, 'node_id': 'PR_kwDOGAOFus47Vwm-', 'html_url': 'https://github.com/seedz-ag/sdz-agent/pull/48', 'diff_url': 'https://github.com/seedz-ag/sdz-agent/pull/48.diff', 'patch_url': 'https://github.com/seedz-ag/sdz-agent/pull/48.patch', 'issue_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/issues/48', 'number': 48, 'state': 'closed', 'locked': False, 'title': 'Bug/restart windows service', 'user': {'login': 'bigjoevtrj', 'id': 4386356, 'node_id': 'MDQ6VXNlcjQzODYzNTY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4386356?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/bigjoevtrj', 'html_url': 'https://github.com/bigjoevtrj', 'followers_url': 'https://api.github.com/users/bigjoevtrj/followers', 'following_url': 'https://api.github.com/users/bigjoevtrj/following{/other_user}', 'gists_url': 'https://api.github.com/users/bigjoevtrj/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/bigjoevtrj/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/bigjoevtrj/subscriptions', 'organizations_url': 'https://api.github.com/users/bigjoevtrj/orgs', 'repos_url': 'https://api.github.com/users/bigjoevtrj/repos', 'events_url': 'https://api.github.com/users/bigjoevtrj/events{/privacy}', 'received_events_url': 'https://api.github.com/users/bigjoevtrj/received_events', 'type': 'User', 'site_admin': False}, 'body': None, 'created_at': '2022-07-13T14:14:36Z', 'updated_at': '2022-07-13T14:15:52Z', 'closed_at': '2022-07-13T14:15:51Z', 'merged_at': '2022-07-13T14:15:51Z', 'merge_commit_sha': 'd2b73a56df39e7326ded5b3e35091f2b79cdf6d3', 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48/commits', 'review_comments_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/pulls/48/comments', 'review_comment_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/issues/48/comments', 'statuses_url': 'https://api.github.com/repos/seedz-ag/sdz-agent/statuses/df9eec15078fab00db007f5087ff4fd7da55edc1', 'head': {'label': 'seedz-ag:bug/restart-windows-service', 'ref': 'bug/restart-windows-service', 'sha': 'df9eec15078fab00db007f5087ff4fd7da55edc1', 'user': {'login': 'seedz-ag', 'id': 88738060, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg4NzM4MDYw', 'avatar_url': 'https://avatars.githubusercontent.com/u/88738060?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/seedz-ag', 'html_url': 'https://github.com/seedz-ag', 'followers_url': 'https://api.github.com/users/seedz-ag/followers', 'following_url': 'https://api.github.com/users/seedz-ag/following{/other_user}', 'gists_url': 'https://api.github.com/users/seedz-ag/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/seedz-ag/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/seedz-ag/subscriptions', 'organizations_url': 'https://api.github.com/users/seedz-ag/orgs', 'repos_url': 'https://api.github.com/users/seedz-ag/repos', 'events_url': 'https://api.github.com/users/seedz-ag/events{/privacy}', 'received_events_url': 'https://api.github.com/users/seedz-ag/received_events', 'type': 'Organization', 'site_admin': False}, 'repo': {'id': 402884026, 'node_id': 'MDEwOlJlcG9zaXRvcnk0MDI4ODQwMjY=', 'name': 'sdz-agent', 'full_name': 'seedz-ag/sdz-agent' ...
