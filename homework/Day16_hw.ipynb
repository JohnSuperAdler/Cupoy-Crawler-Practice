# %% [markdown]
# # Day16
# ## 模擬 HTTP 請求：使用 Requests 套件
# - 了解靜態網頁的爬蟲策略
# - 認識靜態網頁爬蟲的常用套件：Requests
# - Requests 套件實作練習

# %% [markdown]
# ## 作業說明
# 請跟著引導填空程式碼，練習以下題目
# 1. 練習發送 Requests
# 2. 練習帶上 headers
# 3. 練習帶上 payload

# %%
import requests

# %% [markdown]
# ### (1) 練習發送 Requests
# - Wordle
#
# https://www.nytimes.com/games/wordle/index.html

# %%
url = "https://www.nytimes.com/games/wordle/index.html"
r = requests.get(url)
r.encoding = 'utf-8'
print(r.status_code, "\n\n", r.text[:1500])
# Out:
# 200
#
#  <!DOCTYPE html>
# ...

# %% [markdown]
# ### (2) 練習帶上 headers
# - Momo 購物網
#
# https://www.momoshop.com.tw/main/Main.jsp

# %%
url = "https://www.momoshop.com.tw/main/Main.jsp"

headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "accept-encoding": "gzip, deflate, br", 
    "accept-language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    "cookie": '_fbp=fb.3.1658845220076.374335608; wshop=wshop_web_b_1; JSESSIONID=EAD6BA45CB0318A633983BD0BC8B99AD-m1.b1-shop01; firstTimeOpenShop=forever; _ga_ZF0L1038WJ=GS1.1.1658845217.1.0.1658845217.0; _ga=GA1.1.980448997.1658845218; bid=e4e461e3ad82d82895fe2831e0b93b6e; isBI=1; appier_utmz={"csr":"localhost%3A8888","timestamp":1658845219}; _atrk_siteuid=xYK2QyRBMkQitihF; _atrk_ssid=3cY3fZdQGQ8k3MvmqJ7wAN; appier_pv_counterERlDyPL9yO7gfOb=0; appier_page_isView_ERlDyPL9yO7gfOb=f42a524e779bd74dc4d8c3f4c7cf713fea37ab2fbf23e346b8d74d9359dc7aea; appier_pv_counterc7279b5af7b77d1=0; appier_page_isView_c7279b5af7b77d1=f42a524e779bd74dc4d8c3f4c7cf713fea37ab2fbf23e346b8d74d9359dc7aea; _atrk_sessidx=2; _gcl_au=1.1.879083116.1658845220; ARK_ID=JS2750f361feaea1326013a20e3a33abba2750; _mwa_uniCampaignInfo=1658845220442289856.1658845220442; _mwa_uniVisitorInfo=1658845220440753577.1658845220440.1.1658845220442; TN=undefined; CN=undefined; CM=undefined; cto_bundle=z5_sb19yYnIlMkJ0ckM4WEM0UUoydTkxbWg3ZnJCQ1BrOVYwOU5ZMllqaSUyQksweXFqWUg0aDluTmZ5bXlOUW5xeE92a1hoUmZUSDBFeEFIVXVaN2dSeUk0UEZFa0JOTDc0NlN1YTI2N3glMkJyVTVFTWZVampBdnVadnlmaFlGS2I1b01nNUNSdWZNWXFVcERlVTg4dGJiNE8zV1RDUlElM0QlM0Q; _mwa_uniSessionInfo=1658845220441992898.1658845220441.4.1658845221854',
    "user-agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
}
r = requests.get(url, headers=headers)
r.encoding = 'utf-8'
print(r.status_code, "\n\n", r.text[:1500])
# Out:
# 200
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE HTML>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <html lang="zh">
# <head>
# <link rel="shortcut icon" href="/main/favicon.ico"/>
# <link rel="Bookmark" href="/main/favicon.ico"/>
# <link rel="icon" href="/main/favicon.ico" type="image/ico"/>
# <link rel="search" href="/search/openSearch.xml" type="application/opensearchdescription+xml" title="momo購物網"/>
#
#
# <link rel="canonical" href="https://www.momoshop.com.tw">
# <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.momoshop.com.tw">
#
#
# <title>momo&#36092;&#29289;&#32178;</title>
#
#
# <script type="application/ld+json">
# {
# "@context":"https://schema.org",
# "@type":"Organization",
# "url":"https://www.momoshop.com.tw",
# "logo":"https://m.momoshop.com.tw/img/message.png"
# }
# </script>
#
# ...

# %% [markdown]
# ### (3) 練習帶上 payload
# - CNYES 鉅亨網 新聞 API
#
# https://api.cnyes.com/media/api/v1/newslist/category/tw_stock?startAt=1615478400&endAt=1646928000&limit=1000

# %%
url = "https://api.cnyes.com/media/api/v1/newslist/category/tw_stock"
headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
    "accept-encoding": "gzip, deflate, br", 
    "accept-language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6", 
    #"cookie": _______,
    "user-agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'
}
url_params = {
    'startAt': '1615478400',
    'endAt': '1646928000',
    'limit': '1000'
}
r = requests.get(url, headers=headers, params=url_params)
print(r.status_code)
# Out:
# 200

# %%
r.text
# Out:
# '{"items":{"total":20615,"per_page":30,"current_page":1,"last_page":688,"next_page_url":"\\/media\\/api\\/v1\\/newslist\\/category\\/tw_stock?page=2","prev_page_url":null,"from":1,"to":30,"data":[{"isOutsource":0,"content":"&lt;p&gt;\\u5546\\u7528\\u96fb\\u52d5\\u8eca\\u65b0\\u5275 Lordstown Motors (RIDE-US) \\u7e3d\\u88c1 Edward Hightower \\u76f4\\u8a00\\uff0c\\u6240\\u63a8\\u51fa\\u7684\\u96fb\\u52d5\\u76ae\\u5361 Endurance \\u5728\\u7e3d\\u64c1\\u6709\\u6210\\u672c (Total cost of ownership) \\u65b9\\u9762\\u5177\\u6709\\u512a\\u52e2\\uff0c\\u800c Endurance \\u662f\\u7531\\u9d3b\\u6d77 (2317-TW) \\u5354\\u52a9\\u751f\\u7522\\u3002&lt;\\/p&gt;\\n\\n&lt;p&gt;Lordstown \\u53c3\\u52a0\\u7531\\u7f8e\\u570b\\u5de5\\u4f5c\\u5361\\u8eca\\u884c\\u696d\\u5354\\u6703 (NTEA) \\u5728\\u5370\\u7b2c\\u5b89\\u7d0d\\u6ce2\\u91cc\\u65af (\\u5370\\u7b2c\\u5b89\\u7d0d) \\u6240\\u8209\\u884c\\u7684 Work Truck Week 2022 \\u5de5\\u4f5c\\u5361\\u8eca\\u5c55\\uff0c\\u4e26\\u5c55\\u51fa\\u65d7\\u4e0b\\u8eca
# ...

# %%
data = r.json()
data["items"]["data"][0]
# Out:
# {'isOutsource': 0,
#  'content': '&lt;p&gt;商用電動車新創 Lordstown Motors (RIDE-US) 總裁 Edward Hightower 直言，所推出的電動皮卡 Endurance 在總擁有成本 (Total cost of ownership) 方面具有優勢，而 Endurance 是由鴻海 (2317-TW) 協助生產。&lt;/p&gt;\n\n&lt;p&gt;Lordstown 參加由美國工作卡車行業協會 (NTEA) 在印第安納波里斯 (印第安納) 所舉行的 Work Truck Week 2022 工作卡車展，並展出旗下車款 Endurance，也吸引不少人參觀。&lt;/p&gt;\n\n&lt;p&gt;Edward Hightower 則表示，Endurance 是一款獨特的車輛，具備出色的操控性、牽引力控制、扭矩和轉彎半徑組合，相信會受到車隊客戶青睞。&lt;/p&gt;\n\n&lt;p&gt;且與傳統的推進系統相比，Edward Hightowe 指出，Endurance 所使用的移動部件 (Moving Parts) 更少，因此在總擁有成本方面具有優勢。&lt;/p&gt;\n\n&lt;p&gt;目前 Endurance 是由鴻海在俄亥俄州工廠協助製造，預計今年第三季上市，鴻海董事長劉揚偉先前表示，Endurance 量產前的生產計劃都正常進行。&lt;/p&gt;\n',
#  'hasCoverPhoto': 1,
#  'isCategoryHeadline': 1,
#  'isIndex': 1,
#  'newsId': 4830914,
#  'otherProduct': ['TWS:2317:STOCK:COMMON', 'USS:RIDE:STOCK:COMMON'],
#  'payment': 0,
#  'source': '',
#  'stock': ['2317', 'US-RIDE'],
# ...
